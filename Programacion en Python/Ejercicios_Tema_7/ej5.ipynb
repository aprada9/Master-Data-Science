# %% [markdown]
# # Ejercicios 5

# %% [markdown]
# #### 1 Ejercicio

# %% [markdown]
# El fichero [oil_price.csv](./datos/oil_price_monthly.csv) contiene información mensual del precio del petróleo desde el año 1985. Abre el fichero y mira el aspecto que tiene.
# * La primera columna contiene el mes y el año en formato 'yyyy-mm'.
# * La segunda columna contiene el precio del barril expresado en euros.
#
# ----
# * Realiza la carga del fichero utilizando la función __read_csv__ de pandas. El DataFrame creado debe tener como índices la fecha. Ha de llamarse `datos`.

# %%
# Sol:
import pandas as pd
import numpy as np


datos = pd.read_csv("datos/oil_price_monthly.csv",names=['Fecha','Precio'])
datos
# Out:
#        Fecha   Precio
# 0    1985-05  36.6383
# 1    1985-06  35.4184
# 2    1985-07  34.2709
# 3    1985-08  33.8411
# 4    1985-09  34.6826
# 5    1985-10  33.4498
# 6    1985-11  34.1048
# 7    1985-12  29.5807
# 8    1986-01  25.2609
# 9    1986-02  16.8622
# 10   1986-03  13.3181
# 11   1986-04  12.5621
# 12   1986-05  14.2754
# 13   1986-06  12.2961
# 14   1986-07  10.0871
# 15   1986-08  13.5117
# 16   1986-09  13.9921
# 17   1986-10  13.6932
# 18   1986-11  14.4211
# 19   1986-12  15.3397
# 20   1987-01  16.5182
# 21   1987-02  15.2809
# 22   1987-03  15.6204
# 23   1987-04  15.5698
# 24   1987-05  15.9458
# 25   1987-06  16.4063
# 26   1987-07  17.5500
# 27   1987-08  17.0353
# 28   1987-09  16.0591
# 29   1987-10  16.3643
# ..       ...      ...
# 310  2011-03  82.1068
# 311  2011-04  85.1395
# 312  2011-05  79.8296
# 313  2011-06  79.0854
# 314  2011-07  81.7058
# 315  2011-08  76.7140
# 316  2011-09  79.8159
# 317  2011-10  78.9365
# 318  2011-11  81.3574
# 319  2011-12  81.6568
# 320  2012-01  86.2344
# 321  2012-02  89.7464
# 322  2012-03  94.2123
# 323  2012-04  91.3811
# 324  2012-05  86.0061
# 325  2012-06  76.4181
# 326  2012-07  83.3615
# 327  2012-08  90.4529
# 328  2012-09  87.9202
# 329  2012-10  85.5900
# 330  2012-11  84.8372
# 331  2012-12  82.7839
# 332  2013-01  84.1874
# 333  2013-02  86.7123
# 334  2013-03  84.1555
# 335  2013-04  79.3453
# 336  2013-05  79.2452
# 337  2013-06  78.3375
# 338  2013-07  81.8711
# 339  2013-08  82.5541
#
# [340 rows x 2 columns]

# %%
# Rrepresenta gráficamente la evolución de los precios
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

datos.plot(title = 'Evolucion Precios',
                          figsize=(9,4));                           # Tamaño de la figura

# %% [markdown]
# ---
# * Determinar el mes y el año donde por primera vez el precio del petróleo superó los 40 euros, los 60 y los 80 euros.
#     * Primero crea un DataFrame con el mes y el año donde por primera vez el precio del petróleo superó los 40.
#     * En segundo lugar crea un DataFrame con el mes y el año donde por primera vez el precio del petróleo superó los 60.
#     * En tercer lugar crea un DataFrame con el mes y el año donde por primera vez el precio del petróleo superó los 80.
#     * Consulta la ayuda de la función `join` para saber cómo funciona y para qué sirve. Para ello ejecuta `pd.join?`.
#     * Utiliza la función `join` para unir los datos en un unico DataFrame.
#
# La solución es 2005-03, 2007-11, 2008-05.

# %%
#Sol: Creamos el dataframe donde buscaremos todos los datos. (opcional)
df = pd.DataFrame(datos)

# %%
#En primer lugar definimos Fecha1 donde buscamos el primer valor de Fecha donde precio es mayor(greater)de 40. 
#Al haber comprobado que ya está ordendada la tabla no precisa ser ordenada.
Fecha1 = [df.loc[(df[df['Precio'].gt(40)].index[0]), 'Fecha'] ]

#Tras encontrar dicha fecha, creamos el dataframe.
tabla40 = pd.DataFrame( data    = Fecha1,           
                      columns = ['Sup40'])  
tabla40
# Out:
#      Sup40
# 0  2005-03

# %%
 

Fecha2 = [df.loc[(df[df['Precio'].gt(60)].index[0]), 'Fecha'] ]

tabla60 = pd.DataFrame( data    = Fecha2,
                      columns = ['Sup60'])  
tabla60
# Out:
#      Sup60
# 0  2007-11

# %%
Fecha3 = [df.loc[(df[df['Precio'].gt(80)].index[0]), 'Fecha'] ]

tabla80 = pd.DataFrame( data    = Fecha3,
                      columns = ['Sup80'])  
tabla80
# Out:
#      Sup80
# 0  2008-05

# %%
#Hacemos primeramente un join de las 2 primeras tablas, y sobre esa tabla que nace hacemos el join con la última tabla

Fechas = tabla40.join(tabla60)
Fechas = Fechas.join(tabla80)
Fechas
# Out:
#      Sup40    Sup60    Sup80
# 0  2005-03  2007-11  2008-05

# %% [markdown]
# #### 2 Ejercicio

# %% [markdown]
# El fichero [rotterdam_rainfall.txt](./datos/rotterdam_rainfall.txt) recoge los datos de las precipitaciones diarias de la estación meteorológica de Rotterdam en 2012.
#
# * La primera columna representa la fecha
# * La segunda columna representa la cantidad de precipitaciones expresado en 0.1 mm (-1 si es menor a 0.05 mm).
#
# __Notas__:
#
# * Carga los datos en un DataFrame con la función __read_csv__
# * El índice del DataFrame ha de ser la fecha

# %%
# Sol
import pandas as pd
tiempo = pd.read_csv("datos/rotterdam_rainfall_2012.csv",
                     names=['STN','Fecha','Precipitaciones'], 
                     index_col  = 'Fecha',
                    skiprows = 10)  
tiempo.pop('STN')
tiempo
# Out:
#           Precipitaciones
# Fecha
# 20120101              207
# 20120102               -1
# 20120103              144
# 20120104               36
# 20120105               84
# 20120106                8
# 20120107               30
# 20120108               -1
# 20120109                8
# 20120110                0
# 20120111               10
# 20120112                9
# 20120113                4
# 20120114               -1
# 20120115                0
# 20120116                0
# 20120117                0
# 20120118               32
# 20120119              144
# 20120120               -1
# 20120121               35
# 20120122               19
# 20120123               16
# 20120124                5
# 20120125                5
# 20120126               33
# 20120127               -1
# 20120128               -1
# 20120129                0
# 20120130                1
# ...                   ...
# 20121202               93
# 20121203               52
# 20121204               96
# 20121205               29
# 20121206                7
# 20121207              107
# 20121208                1
# 20121209              102
# 20121210               16
# 20121211                2
# 20121212               -1
# 20121213               -1
# 20121214              103
# 20121215                8
# 20121216               24
# 20121217               31
# 20121218               16
# 20121219                0
# 20121220               68
# 20121221                9
# 20121222              224
# 20121223               76
# 20121224               32
# 20121225              125
# 20121226               45
# 20121227               27
# 20121228               18
# 20121229                2
# 20121230               23
# 20121231               50
#
# [366 rows x 1 columns]

# %% [markdown]
# * Modifica los valores de la cantidad de precipitaciones a 0 cuando su valor sea -1.

# %%
# Sol:
tiempo[tiempo.Precipitaciones == -1] = 0

tiempo
# Out:
#           Precipitaciones
# Fecha
# 20120101              207
# 20120102                0
# 20120103              144
# 20120104               36
# 20120105               84
# 20120106                8
# 20120107               30
# 20120108                0
# 20120109                8
# 20120110                0
# 20120111               10
# 20120112                9
# 20120113                4
# 20120114                0
# 20120115                0
# 20120116                0
# 20120117                0
# 20120118               32
# 20120119              144
# 20120120                0
# 20120121               35
# 20120122               19
# 20120123               16
# 20120124                5
# 20120125                5
# 20120126               33
# 20120127                0
# 20120128                0
# 20120129                0
# 20120130                1
# ...                   ...
# 20121202               93
# 20121203               52
# 20121204               96
# 20121205               29
# 20121206                7
# 20121207              107
# 20121208                1
# 20121209              102
# 20121210               16
# 20121211                2
# 20121212                0
# 20121213                0
# 20121214              103
# 20121215                8
# 20121216               24
# 20121217               31
# 20121218               16
# 20121219                0
# 20121220               68
# 20121221                9
# 20121222              224
# 20121223               76
# 20121224               32
# 20121225              125
# 20121226               45
# 20121227               27
# 20121228               18
# 20121229                2
# 20121230               23
# 20121231               50
#
# [366 rows x 1 columns]

# %% [markdown]
# -----
# * Calcula el día que ha tenido mayor cantidad de precipitación y la cantidad de precipitación

# %%
# Sol:
tiempo.Precipitaciones.max()
Maxprec = tiempo.ix[tiempo['Precipitaciones'].idxmax()]
MaxPrecDF = pd.DataFrame(Maxprec)
MaxPrecDF
# Out:
#                  20121222
# Precipitaciones       224

# %% [markdown]
# ## References

# %% [markdown]
# http://nbviewer.ipython.org/github/mbakker7/exploratory_computing_with_python/tree/master/

# %% [markdown]
# -----
