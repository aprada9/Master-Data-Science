# %% [markdown]
# # Acceso a los datos de la web
#
# ### Web Scraping

# %% [markdown]
# El __Web Scraping__ (o Scraping) son un conjunto de técnicas que se utilizan para obtener de forma automática el contenido que hay en páginas web a través de su código HTML.
# * Es una opción cuando no hay API's para extraer datos de la web
# * Otros términos:
#     * "Spydering the web"
#     * "Web crawling"
#
# Las técnicas de Scraping se pueden enmarcar dentro del campo del Big Data en la primera fase de recolección de datos para su posterior almacenamiento, tratamiento y visualización.
#
# El uso de estas técnicas tienen como finalidad recopilar grandes cantidades de datos de diferentes páginas web cuyo uso posterior puede ser muy variado:
#
#   * homogenización de datos,
#   * tratamiento de contenido para la extracción de conocimiento,
#   * complementar datos en una web, etc.

# %% [markdown]
# __Realizar una petición__
#
# La página web con la que vamos a jugar es:
# "https://es.wikipedia.org/wiki/Anexo:Municipios_de_la_Comunidad_de_Madrid"
#  que contiene datos de la lista de municipios de la Comunidad de Madrid.
#
# Para acceder al contenido de una página web usamos el protocolo HTTP Request/Response.
#
# A continuación adjunto una función capaz de hacer una conexión HTTP para acceder a una página web y extraer información.

# %%
import requests

url = "https://www.fnac.es/n713/Libros-de-bolsillo-mas-vendidos"

# Realizamos la petición HTTP a la web
response = requests.get(url)

# %% [markdown]
# * La función __get__ del módulo __request__ de Python abre una conexión con el servidor donde se encuentra la url (parámetro de  __get__) y manda la petición.
#
# * La respuesta del servidor se almacena en la variable (u objeto) _response_.
#
# * A partir del objeto _response_, que almacena muchos datos relacionados con la petición HTTP (cabeceras, cookies, etc.) obtenemos el __status_code__ y el __HTML__ (como un string) de la web.

# %%
response.status_code        # atributo status_code: nos indicará si la petición 
                            # ha tenido éxito
# Out:
# 200

# %%
# Comprobamos que la petición nos devuelve un Status Code = 200
statusCode = response.status_code 

if statusCode == 200:
    print('La petición ha ido bien')
else:
    print('Problemas con la petición...')
# Out:
# La petición ha ido bien

# %% [markdown]
# A partir del objeto __response__, que almacena muchos datos relacionados con la petición HTTP (cabeceras, cookies, etc.) obtenemos el __status_Code__ y el __HTML__ (como un string) de la web.

# %%
htmlText = response.text

# %% [markdown]
# __Extraer información__
#
# A partir del string __htmlText__ que representa el código interno de la pagina web, parseamos la web para extraer la información que nos interesa.
#
# Mecanismos:
#
# * Usar expresiones regulares para localizar cadenas: esto puede ser muy laborioso, y pesado ...
#
#
#
# * Usar alguna de las librerías de Python que permiten parsear el texto HTML de forma cómoda.
#     * __BeautifullSoup__
#     * __Scrapy__
#     * __Selenium__
#
#
# __BeautifulSoup__  nos aporta los métodos necesarios (y muy bien optimizados) para obtener el contenido que hay entre las etiquetas HTML.

# %%
from bs4 import BeautifulSoup

# Pasamos el contenido HTML de la web a un objeto BeautifulSoup()
soup = BeautifulSoup(htmlText, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE doctype html>
#
# <!--[if IE 9]>         <html class="no-js ie9" lang="es-ES"> <![endif]-->
# <!--[if gt IE 9]><!--> <html class="no-js" lang="es-ES"> <!--<![endif]-->
# <head id="HtmlHead1_Head1">
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="DA361407407072F944FEC313FFFB02E4" name="msvalidate.01"/>
# <meta content="https://secure.fnac.es/basket/view" name="cart-view-url"/>
# <meta content="https://secure.fnac.es/basket/add" name="cart-add-url"/>
# <meta content="https://secure.fnac.es/basket/oneclick" name="cart-oneclick-url"/>
# <meta content="https://secure.fnac.es/" name="secure-url"/>
# <meta content="https://secure.fnac.es/Account/Logon/Logon.aspx?LogonType=Standard&amp;PageAuth=X&amp;pagepar=PID%3d713&amp;PageRedir=https%3a%2f%2fwww.fnac.es%2fNav%2fCore%2fSearch%2fResultList.aspx" name="login-url"/>
# <meta content="https://www.fnac.es/Legacy/Img/" name="images-url"/>
# <meta content="" name="pathname"/>
# <meta content="/" name="cookies-path"/>
# <meta content=".fnac.es" name="cookies-hostname"/>
# <meta content="fjs" name="doublerun"/>
# <meta content="cfls" name="doublerun-call"/>
# <meta content="https://www.fnac.es/static/sf/236jbv9inRteR2_egqszhAMgSsk0/nav/js/vendors/flashmediaelement.swf" name="mediaelement-swf-url"/>
# <meta content="https://www.fnac.es/static/sf/xbLi6c-K8H7a_GqTSwn4OStqdUc0/nav/core/static/localstorage.html" name="localstorageiframe"/>
# <meta content="False" name="mobile-device"/><meta content='(PICS-1.1 "http://www.rsac.org/ratingsv01.html" l gen true comment "RSACi North America Server" by "webmaster@fnac.com" for "https://www.fnac.com/" on "1997.06.30T14:21-0500" r (n 0 s 0 v 0 l 0))' http-equiv="PICS-Label"><link href="https://www.fnac.es/n713/Libros-de-bolsillo-mas-vendidos" rel="canonical"/>
# <link href="https://www.fnac.es/nav/images/favicon.ico" rel="shortcut icon"/>
# <link href="https://www.fnac.es/static/ls/ceohEXxiPU8GDQKe1a48Z9Ytty80/nav/css/layout.css" rel="stylesheet"/>
# <link href="https://www.fnac.es/static/ls/PJPKkHmWGaWCzT8w34msRH4UxTw0/nav/css/search.css" rel="stylesheet"/>
# <link href="https://www.fnac.es/static/css/53axRKVukfxV5gpe3aVYRduMYjY0/nav/css/legacy/search-legacy.css" rel="stylesheet"/>
# <script defer="" src="//cdn.early-birds.fr/tenants/fnac-es/earlybirds-full.min.js"></script>
# <script type="text/javascript">
#     var FnacAnalytics = [];
#
#     FnacAnalytics["arbo_niv1"] = "Tous_produits";
#     FnacAnalytics["arbo_niv2"] = "";
#     FnacAnalytics["arbo_niv3"] = "";
#     FnacAnalytics["arbo_niv4"] = "";
#     FnacAnalytics["arbo_niv5"] = "";
#     FnacAnalytics["arbo_niv6"] = "";
#     FnacAnalytics["page_name"] = "Resultat_Recherche_Tous_Produits";
#
#     FnacAnalytics["env_language"] = "es-ES";
#     FnacAnalytics["env_country"] = "ES";
#
#     FnacAnalytics["user_id"] = "";
#     FnacAnalytics["user_segment"] = "Non-Adherent";
#     FnacAnalytics["user_segment_type"] = "";
#     FnacAnalytics["user_age"] = "";
#     FnacAnalytics["user_gender"] = "";
#     FnacAnalytics["user_subscription_date"] = "";
#     FnacAnalytics["user_subscription_newsletter"] = "";
#     FnacAnalytics["user_sid"] = ""
#
#     FnacAnalytics["express_plus"] = "";
#     FnacAnalytics["eligibility_ express_plus_trial"] = "";
#
#     FnacAnalytics["product_unitprice_ati"] = "";
#     FnacAnalytics["product_discount_ati"] = "";
#     FnacAnalytics["product_unitprice_tf"] = "";
#     FnacAnalytics["product_discount_tf"] = "";
#     FnacAnalytics["product_currency"] = "";
#     FnacAnalytics["product_trademark"] = "";
#     FnacAnalytics["product_url_page"] = "";
#     FnacAnalytics["product_picture_url"] = "";
#     FnacAnalytics["product_breadcrumb_id"] = "";
#     FnacAnalytics["product_id"] = "";
#     FnacAnalytics["product_ref_id"] = "";
#
#     FnacAnalytics["cart_id"] = "";
#
#     FnacAnalytics["order_id"] = "";
#     FnacAnalytics["order_amount"] = "";
#     FnacAnalytics["order_amount_ati_with_sf"] = "";
#     FnacAnalytics["order_amount_tf_with_sf"] = "";
#     FnacAnalytics["order_currency"] = "";
#     FnacAnalytics["order_new_client"] = "";
#     FnacAnalytics["order_nb_products"] = "0";
#     FnacAnalytics["order_promo_code"] = "";
#     FnacAnalytics["order_shipping_method"] = "";
# </script>
# <script language="JavaScript1.2" src="https://www.fnac.es/static/js/Gv3OSc-d38XPj0Y3VnlybJm2RDw0/legacy/js/mbox.js" type="text/javascript"></script>
# <script defer="" src="//www3.smartadserver.com/config.js?nwid=110"></script>
# <script>
#     var sasTarget, myTagBan, myTagPave1, myTagPave2, myTagPave3, myTagHab, myTagSky;
#     window.addEventListener('load', function () {
#         if (window.sas) {
#
#
#             var WDomSas = encodeURIComponent(window.location.hostname);
#             var replaceDict = { "è": "e", "é": "e", "ê": "e", "à": "a", "á": "a", "ç": "c", " ": "-", ",": "-", "&": "ET", "!": "-", "?": "-", "/": "-", "(": "-", ")": "-", ":": "-", "'": "-" };
#
#             sasTarget = '';
#             var params = ['user_segment', 'user_segment_type', 'user_age', 'express_plus', 'eligibility_ express_plus_trial', 'arbo_niv1',
#                 'arbo_niv2', 'arbo_niv3', 'arbo_niv4', 'arbo_niv5', 'arbo_niv6', 'page_name', 'order_amount', 'order_new_client',
#                 'order_shipping_method', 'order_promo_code', 'order_nb_products', 'product_id', 'product_ref_id'];
#
#
#             sasTarget = params.map(function (param) {
#                 // remove falsy value (to remove empty string value)
#                 if (typeof FnacAnalytics !== 'undefined' && !!FnacAnalytics[param]) {
#                     return [param, FnacAnalytics[param].replace(/[^\w]/g, function (char) { return replaceDict[char] || char })].join('=') + ";";
#                 }
#             }).join('');
#
#             sasTarget += 'ddiff=' + WDomSas + ';'
#             sasTarget = sasTarget.slice(0, -1);
#
#
#             sas.setup({ domain: '//www3.smartadserver.com', async: true, renderMode: 0 });
#         }
#
#         if (typeof sasTarget != 'undefined' && $("#sas_34399").length) {
#             sas.call('std', {
#                 siteId: 72544,
#                 pageId: 574860,
#                 formatId: 34399,
#                 target: sasTarget
#             });
#         }
#
#         if (typeof sasTarget != 'undefined' && $("#sas_41537").length) {
#             var RN = new String(Math.random());
#             var RNS = RN.substring(2, 11);
#             var sas_ajax = true;
#             myTagPave1 = document.createElement("script");
#             myTagPave1.src = '//www3.smartadserver.com/ac?out=js&nwid=1574&siteid=122511&pgname=' + $("#sas_41537").data('page') + '&fmtid=41537&tgt=' + sasTarget + '&visit=m&tmstp=' + RNS + '&clcturl=[countgo]';
#             myTagPave1.async = "async";
#             document.getElementsByTagName("head")[0].appendChild(myTagPave1);
#         }
#
#         if (typeof sasTarget != 'undefined' && $("#sas_41538").length) {
#             var RN = new String(Math.random());
#             var RNS = RN.substring(2, 11);
#             var sas_ajax = true;
#             myTagBan = document.createElement("script");
#             myTagBan.src = '//www3.smartadserver.com/ac?out=js&nwid=1574&siteid=122511&pgname=' + $("#sas_41538").data('page') + '&fmtid=41538&tgt=' + sasTarget + '&visit=m&tmstp=' + RNS + '&clcturl=[countgo]';
#             myTagBan.async = "async";
#             document.getElementsByTagName("head")[0].appendChild(myTagBan);
#         }
#
#         if (typeof sasTarget != 'undefined' && $("#sas_36020").length) {
#             var RN = new String(Math.random());
#             var RNS = RN.substring(2, 11);
#             var sas_ajax = true;
#             myTagPave2 = document.createElement("script");
#             myTagPave2.src = '//www3.smartadserver.com/ac?out=js&nwid=1574&siteid=122511&pgname=' + $("#sas_36020").data('page') + '&fmtid=36020&tgt=' + sasTarget + '&visit=m&tmstp=' + RNS + '&clcturl=[countgo]';
#             myTagPave2.async = "async";
#             document.getElementsByTagName("head")[0].appendChild(myTagPave2);
#         }
#
#         if (typeof sasTarget != 'undefined' && $("#sas_36022").length) {
#             var RN = new String(Math.random());
#             var RNS = RN.substring(2, 11);
#             var sas_ajax = true;
#             myTagBan = document.createElement("script");
#             myTagBan.src = '//www3.smartadserver.com/ac?out=js&nwid=1574&siteid=122511&pgname=' + $("#sas_36022").data('page') + '&fmtid=36022&tgt=' + sasTarget + '&visit=m&tmstp=' + RNS + '&clcturl=[countgo]';
#             myTagBan.async = "async";
#             document.getElementsByTagName("head")[0].appendChild(myTagBan);
#         }
#
#         if (typeof sasTarget != 'undefined' && $("#sas_51039").length) {
#             var RN = new String(Math.random());
#             var RNS = RN.substring(2, 11);
#             var sas_ajax = true;
#             myTagHab = document.createElement("script");
#             myTagHab.src = '//www3.smartadserver.com/ac?out=js&nwid=1574&siteid=122511&pgname=' + $("#sas_51039").data('page') + '&fmtid=51039&tgt=' + sasTarget + '&visit=m&tmstp=' + RNS + '&clcturl=[countgo]';
#             myTagHab.async = "async";
#             document.getElementsByTagName("head")[0].appendChild(myTagHab);
#         }
#
#         if (typeof sasTarget != 'undefined' && $("#sas_41543").length) {
#             var RN = new String(Math.random());
#             var RNS = RN.substring(2, 11);
#             var sas_ajax = true;
#             myTagBan = document.createElement("script");
#             myTagBan.src = '//www3.smartadserver.com/ac?out=js&nwid=1574&siteid=122511&pgname=' + $("#sas_41543").data('page') + '&fmtid=41543&tgt=[sas_target]&visit=m&tmstp=' + RNS + '&clcturl=[countgo]';
#             myTagBan.async = "async";
#             document.getElementsByTagName("head")[0].appendChild(myTagBan);
#         }
#
#         if (typeof sasTarget != 'undefined' && $("#sas_47232").length) {
#             var RN = new String(Math.random());
#             var RNS = RN.substring(2, 11);
#             var sas_ajax = true;
#             myTagBan1 = document.createElement("script");
#             myTagBan1.src = '//www3.smartadserver.com/ac?out=js&nwid=1574&siteid=122511&pgname=' + $("#sas_47232").data('page') + '&fmtid=47232&visit=m&tmstp=' + RNS + '&clcturl=[countgo]';
#             myTagBan1.async = "async";
#             document.getElementsByTagName("head")[0].appendChild(myTagBan1);
#         }
#
#         if (typeof sasTarget != 'undefined' && $("#sas_47233").length) {
#             var RN = new String(Math.random());
#             var RNS = RN.substring(2, 11);
#             var sas_ajax = true;
#             myTagSky = document.createElement("script");
#             myTagSky.src = '//www3.smartadserver.com/ac?out=js&nwid=1574&siteid=122511&pgname=' + $("#sas_47233").data('page') + '&fmtid=47233&tgt=' + sasTarget + '&visit=m&tmstp=' + RNS + '&clcturl=[countgo]';
#             myTagSky.async = "async";
#             document.getElementsByTagName("head")[0].appendChild(myTagSky);
#         }
#
#     }, false);
# </script>
# <script src="https://www.fnac.es/static/jsg/F_1pDeE3HiYuIwBbiSjndsN9RwI0/header1.js"></script>
# <meta content="Fnac te propone 100 referencias Libros de bolsillo más vendidos, con recogida gratis en tienda en 1 hora. 5 % de descuento para Socios. Todos nuestros productos u otros productos de nuestro Universo Libros." name="description"><link href="https://www.fnac.es/n713/Libros-de-bolsillo-mas-vendidos?PageIndex=2" rel="next"><title>
# 	Libros de bolsillo más vendidos - Libros - Fnac.es
# </title></link></meta></meta></head>
# <body class="search " data-user-is-authenticated="false" data-user-is-identified="false">
# <!--[if lt IE 9]>
# <style>html, body { overflow: hidden !important; }</style>
# <div style="height: 100%; width: 100%; position: fixed; left: 0; z-index: 999998; top: 0; background: #232323">
#     <img width="1024" height="673" style="right: 0; position: absolute; left: 0; margin: auto; z-index: 999999; display: block; top: 0; bottom: 0; border: 0;" src="https://static.fnac-static.com/multimedia/fnacdirect/publi/popinIe8-ES.jpg" usemap="#ie8Popin" alt="">
#     <map name="ie8Popin">
#         <area alt="Google Chrome" title="Google Chrome" href="https://www.google.com/intl/es/chrome/browser/desktop/index.html" coords="355,498,42" shape="circle" />
#         <area alt="Mozilla Firefox" title="Mozilla Firefox" href="https://www.mozilla.org/es/firefox/new/" coords="458,496,45" shape="circle" />
#         <area alt="Apple Safari" title="Apple Safari" href="http://www.apple.com/safari/" coords="564,496,42" shape="circle" />
#         <area alt="Microsoft Internet Explorer" title="Microsoft Internet Explorer" href="https://www.microsoft.com/es-es/download/internet-explorer.aspx" coords="667,496,50" shape="circle" />
#     </map>
# </div>
# <![endif]-->
# <script>
#     var global = eval({"data":{"environment":{"url":"https://www.fnac.es/n713/Libros-de-bolsillo-mas-vendidos","title":"Libros de bolsillo más vendidos","meta_title":"Libros de bolsillo más vendidos - Libros - Fnac.es","nb_results_number":100,"nb_results_text":null,"current_page_number":1,"current_page_text":null,"last_page_number":5,"query":{"text":null,"id":713,"type":"Node","disabled_keywords":0,"search_debug":0,"categories":null,"first_time":false,"versionArbo":null,"filters":null,"nb_element_per_page":20,"page_index":1,"sort_option":0,"sort_direction":0,"score_limit":"-1.0","new_facet":"True","double_facet":"True","facet_information":null,"multibuy_data":{"opc_code1":null,"opc_code2":null}}},"context":{"nb_per_page":{"content":null,"value":20},"view_mode":{"current":"list","is_multibuy":false},"favorite_shop":null,"omniture":{"html":null},"pager_bottom":null,"filters":{"price":{"min":0,"max":30,"current":{"max":null,"min":0}},"content":null}},"navigation":{"breadcrumb":null,"linked_searches":null},"content":{"body":{"html":null,"mode":"Full","lazy":null},"comparer":{"html":null},"multibuy":{"html":null,"message":null},"histonav":{"html":null},"users_advices":null}},"update":{"request":{"type":null,"value":null},"response":{"statut":0,"actions":[]}}});
# </script>
# <!-- - - - - - - Start content - - - - - - -->
# <div class="legacy">
# <header class="Header Header--legacy js-Header">
# <a class="Sidebar-toggler js-SlideNav-toggler" href="#">
# <span class="burger">
# <span class="burger1"></span>
# <span class="burger2"></span>
# <span class="burger3"></span>
# <span class="burger4"></span>
# </span>
# </a>
# <!-- header logo -->
# <div class="logo">
# <a class="fnac-logo" href="https://www.fnac.es/">Fnac.es</a>
# <span class="fnac-logoBaseline"><a href="https://www.fnac.es/fnacexpress"><span class="fnac-logoBaseline--blue"><strong>FnacExpress +</strong></span> Hazte Socio</a></span>
# </div>
# <div class="container-fluid navigation-wrapper js-headerSearchView">
# <div class="col-sm-14 col-md-14 col-lg-9 Header-search js-Header-search">
# <div class="formBox formBox-reg">
# <form accept-charset="UTF-8" action="https://www.fnac.es/SearchResult/ResultList.aspx" id="QuickSearchForm" method="GET" name="QuickSearchForm">
# <fieldset>
# <div class="boxSelect">
# <select class="realSelect" name="SCat">
# <option value="0!1">Todos los productos</option><option value="2!1">Libros</option><option value="14!1">Papelería</option><option value="3!1">Música</option><option value="9!1">Instrumentos musicales</option><option value="4!1">Cine y Series TV</option><option value="5!1">Videojuegos</option><option value="7!1">Juegos y juguetes</option><option value="8!1">Tecnología</option><option value="11!1">Merchandising</option><option value="23!1">Hogar</option><option value="24!1">Juegos de tablero,  cartas y rol</option><option value="25!1">Cofres experiencia</option><option value="26!1">Bebé</option>
# </select>
# </div>
# <input class="text js-HeaderSearch-input" id="Fnac_Search" name="Search" placeholder="¿Qué estás buscando?" type="text" value=""/>
# <input name="sft" type="hidden" value="1"/>
# <input id="QuickSearchFormSa" name="sa" type="hidden" value="0"/>
# <button class="js-btSubmit btSubmit" title="Buscar" type="submit"><i class="icon icon_i_095_Search"></i></button>
# </fieldset>
# </form>
# </div>
# <button class="HeaderSearch-close js-HeaderSearch-close"><i class="icon icon_i_039_cross_01"></i></button>
# </div>
# <div class="col-xs-24 col-sm-10 col-md-10 col-lg-15 Header-tabs js-HeaderTabs">
# <ul class="col-xs-24 col-sm-24 col-md-24 tab-header">
# <li class="Header-searchToggle tab-top">
# <a class="HeaderSearch-open js-HeaderSearch-open search" href="#"></a>
# </li>
# <li class="col-xs-6 col-md-6 tab-top js-HeaderTabHelp">
# <a class="help" data-panel="help" href="https://ayuda.fnac.es/">
# <div class="header-bloc-title-container">
# <div class="header-bloc-title">
# <span class="tab-txt">¿Necesitas ayuda?</span>
# </div>
# </div>
# </a>
# </li>
# <li class="col-xs-6 col-md-7 tab-top js-StoreContainer js-HeaderTabStore">
# <a class="about js-HeaderTab-toggle" data-header-tab="store" data-panel="store-gen" href="https://www.fnac.es/localiza-tiendas-fnac/w-4">
# <div class="header-bloc-title-container">
# <div class="header-bloc-title">
# <span class="tab-txt">
#                     Tiendas
#                 </span>
# </div>
# </div>
# </a>
# </li>
# <li class="col-xs-6 col-md-6 tab-top js-HeaderTabAccount">
# <a class="account js-HeaderTab-toggle" data-header-tab="account" data-usertype="unconnected" href="https://secure.fnac.es/account/personal-information?LogonType=StandardCreation&amp;PageRedir=https%3a%2f%2fwww.fnac.es%2f">
# <div class="header-bloc-title-container">
# <div class="header-bloc-title">
# <span class="tab-txt">Mi cuenta</span>
# </div>
# </div>
# </a>
# </li>
# <li class="col-xs-6 col-md-5 tab-top HeaderTab js-HeaderTabBasket">
# <a class="cart HeaderTab-control HeaderTab-control--basket js-HeaderTab-toggle" data-header-tab="basket" href="https://secure.fnac.es/orderpipe?pipe=pop&amp;reset=1" rel="nofollow">
# <span class="js-CartCount CartCount CartCount--empty " data-maxlabel="99+">
# </span>
# <div class="header-bloc-title-container">
# <div class="header-bloc-title">
# <span class="tab-txt">
#
#         Mi cesta
#       </span>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </header>
# <div class="Main-exitMenu Main-exitMenu--inverse js-Main-exitSideBar"></div>
# <div class="Main-exitMenu js-Main-exitSlideNav"></div>
# <div class="Shutter-wrapper js-HeaderTab-content"></div>
# <div class="CategoryNav-wrapper js-CategoryNav-wrapper"></div>
# <div class="Main-marketingHeader">
# <div class="promo js-scrollPasteToolbar">
# <ul class="promo-List">
# <li class="promo-ListItem">
# <a class="promo-ListItemLink" href="/condiciones_031#bl=marktlink2">
# <img alt="" class="promo-ListItemImg" src="https://static.fnac-static.com/es-ES/fch/01/img/2d6bb977-6b9f-4131-b992-20cfe1bf1215.png" title=""/>
# <span class="promo-ListItemLabel">Días del Socio -15%</span>
# </a>
# </li>
# <li class="promo-ListItem">
# <a class="promo-ListItemLink" href="/fnacexpress#bl=marktlink3">
# <img alt="" class="promo-ListItemImg" src="https://static.fnac-static.com/es-ES/fch/01/img/89607b89-c701-49ba-ba74-ed5f391a72dd.png" title=""/>
# <span class="promo-ListItemLabel">¡Hazte Socio por sólo 10€!</span>
# </a>
# </li>
# <li class="promo-ListItem">
# <a class="promo-ListItemLink" href="/home/book.aspx#bl=marktlink4">
# <img alt="" class="promo-ListItemImg" src="https://static.fnac-static.com/es-ES/fch/01/img/0fe3ab17-863c-44a1-8757-6e27efb83873.png" title=""/>
# <span class="promo-ListItemLabel">-5% en libros</span>
# </a>
# </li>
# <li class="promo-ListItem">
# <a class="promo-ListItemLink" href="/s83537#bl=marktlink5">
# <img alt="" class="promo-ListItemImg" src="https://static.fnac-static.com/es-ES/fch/01/img/648c75b0-02d5-492b-b2f1-de0af0edf203.png" title=""/>
# <span class="promo-ListItemLabel">Todas las ofertas</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <a class="SlideNav-toggler js-SlideNav-toggler" href="#">
# <span class="burger">
# <span class="burger1"></span>
# <span class="burger2"></span>
# <span class="burger3"></span>
# <span class="burger4"></span>
# </span>
#     Todos los universos
#   </a>
# <div class="SlideNav nano">
# <div class="nano-content ScrollWrapper SlideNav-loadWrapper"></div>
# </div>
# </div>
# <div class="Sidebar js-Sidebar">
# <div id="col_gauche">
# <div class="SearchNav">
# <!--<div class="SearchNav SearchNav-ab SearchNav-ab-categories">-->
# <a class="SlideNav-toggler js-SlideNav-toggler" href="#">
# <span class="burger">
# <span class="burger1"></span>
# <span class="burger2"></span>
# <span class="burger3"></span>
# <span class="burger4"></span>
# </span>
#         Todos los universos
#     </a>
# <a class="SidebarPromo-link" href="https://www.fnac.es/home/book.aspx"><i class="icon icon_i_057_arrow_left_01"></i>Libros</a>
# <div class="Sidebar-title">
# 	Libros de bolsillo más vendidos
# </div>
# <div class="category-menu">
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">actualidad<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem categoryMenu-menuItem--special">
# <a class="categoryMenu-link" href="https://www.fnac.es/n28782/Lo-mas-reservado">Lo más reservado</a>
# </dd>
# <dd class="categoryMenu-title">
#                 Libros de bolsillo más vendidos
#             </dd>
# <dd class="categoryMenu-menuItem categoryMenu-menuItem--special">
# <a class="categoryMenu-link" href="https://www.fnac.es/n710/Libros-mas-vendidos">Libros más vendidos</a>
# </dd>
# <dd class="categoryMenu-menuItem categoryMenu-menuItem--special">
# <a class="categoryMenu-link" href="https://www.fnac.es/n91427/Libros-con-regalo-exclusivo">Libros con regalo exclusivo</a>
# </dd>
# <dd class="categoryMenu-menuItem categoryMenu-menuItem--special">
# <a class="categoryMenu-link" href="https://www.fnac.es/n90144/Libros-firmados">Libros firmados</a>
# </dd>
# <dd class="categoryMenu-menuItem categoryMenu-menuItem--special">
# <a class="categoryMenu-link" href="https://www.fnac.es/s89968/Proximos-lanzamientos-en-libros">Próximos lanzamientos en libros</a>
# </dd>
# <dd class="categoryMenu-menuItem categoryMenu-menuItem--special">
# <a class="categoryMenu-link" href="https://www.fnac.es/n78625/Libros-recomendados">Libros recomendados</a>
# </dd>
# <dd class="categoryMenu-menuItem categoryMenu-menuItem--special">
# <a class="categoryMenu-link" href="https://www.fnac.es/s5478/Libros-de-oferta">Libros de oferta</a>
# </dd>
# </dl>
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">Autores más buscados<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n96781/Dolores-Redondo">Dolores Redondo</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n96782/Elisabet-Benavent">Elísabet Benavent</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n96783/Marie-Kondo">Marie Kondo</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n96790/Ildefonso-Falcones">Ildefonso Falcones</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n96786/Megan-Maxwell">Megan Maxwell</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n96787/Almudena-Grandes">Almudena Grandes</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n96784/Camilla-Lackberg">Camilla Läckberg</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n96788/Dan-Brown">Dan Brown</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n96785/Fernando-Aramburu">Fernando Aramburu</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n96789/Ken-Follett">Ken Follett</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n99703/Stephen-King">Stephen King</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n99704/Isabel-Allende">Isabel Allende</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n99705/Paula-Hawkins">Paula Hawkins</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n96791/Don-Winslow">Don Winslow</a></dd>
# </dl>
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">Libro infantil<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s1867/Libros-infantiles">Libros infantiles</a></dd>
# </dl>
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">Literatura juvenil<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s19439/Literatura-juvenil">Literatura juvenil</a></dd>
# </dl>
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">Cómics<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s339/Comics-novela-grafica-manga-y-superheroes">Cómics, novela gráfica, manga y superhéroes</a></dd>
# </dl>
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">Literatura<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s332/Literatura-universal-narrativa-poesia-y-teatro">Literatura universal: narrativa, poesía y teatro</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s724/Novela-policiaca-y-terror">Novela policíaca y terror</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s725/Novela-historica-y-de-aventuras">Novela histórica y de aventuras</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s726/Novela-de-Ciencia-Ficcion-y-Fantasy">Novela de Ciencia Ficción y Fantasy</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s727/Novela-romantica">Novela romántica</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s3838/Libros-de-viajes">Libros de viajes</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s1064/Libros-de-humor">Libros de humor</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s2455/Literatura-gay-y-lesbiana">Literatura gay y lesbiana</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s1065/Libro-erotico">Libro erótico</a></dd>
# </dl>
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">Biografía y crítica literaria<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s2466/Biografias-linguistica-y-critica-literaria">Biografías, lingüística y crítica literaria</a></dd>
# </dl>
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">Cultura y Sociedad<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s342/Artes">Artes</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s341/Ensayo">Ensayo</a></dd>
# </dl>
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">Naturaleza y Tiempo Libre<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s44180/Libros-de-cocina-y-gastronomia">Libros de cocina y gastronomía</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s343/Libro-practico">Libro práctico</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s344/Guias-de-viaje">Guías de viaje</a></dd>
# </dl>
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">Conocimiento<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s345/Libros-de-informatica-empresa-y-derecho">Libros de informática, empresa y derecho</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s346/Diccionarios-y-metodos-para-aprender-idiomas">Diccionarios y métodos para aprender idiomas</a></dd>
# </dl>
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">Libros de bolsillo<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s331/Libros-de-bolsillo">Libros de bolsillo</a></dd>
# </dl>
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">Libros en otros idiomas<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s347/Libros-en-catalan">Libros en catalán</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s16585/Libros-en-gallego">Libros en gallego</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s17469/Libros-en-euskera">Libros en euskera</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s5714/Libros-en-ingles">Libros en inglés</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s6934/Libros-en-frances">Libros en francés</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s19048/Libros-en-aleman">Libros en alemán</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s24412/Libros-en-italiano">Libros en italiano</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n95876/Libros-en-portugues">Libros en portugués</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n95878/Libros-en-arabe">Libros en árabe</a></dd>
# </dl>
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">Papelería<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s11711/Articulos-de-papeleria-libreria-y-regalo">Artículos de papelería, librería y regalo</a></dd>
# </dl>
# <dl class="categoryMenu-list">
# <dt class="categoryMenu-title js-category-toggler">Especiales FNAC<i class="icon icon_i_108_plus"></i><i class="icon icon_i_109__minus"></i></dt>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n96065/Pierdete-en-el-bosque">Piérdete en el bosque</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n96167/Libros-en-cartelera">Libros en cartelera</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s45626/Libro-antiguo-y-de-ocasion">Libro antiguo y de ocasión</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n46252/Aquellos-maravillosos-libros">Aquellos maravillosos... libros</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s49933/En-femenino">En femenino</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n90285/Alianza-Literatura">Alianza Literatura</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s96748/Bolsas-Fnac-2017">Bolsas Fnac 2017</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/s97230/Bullying">Bullying</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n99474/Libros-con-orgullo">Libros con orgullo</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n102038/Libros-con-gastos-de-envio-gratis">Libros con gastos de envío gratis</a></dd>
# <dd class="categoryMenu-menuItem"><a class="categoryMenu-link" href="https://www.fnac.es/n102307/Los-libros-imprescindibles-del-Otono">Los libros imprescindibles del Otoño</a></dd>
# </dl>
# </div>
# <div class="sticky">
# <div class="blockTitle">
#         FILTRAR
#
#     </div>
# <div class="filters Recall hide">
# <div class="Recall-title">
#         Filtros activos
#     </div>
# <div class="Recall-panel">
# <span class="filters">
# </span>
# </div>
# <span class="reinit hide">
# <a data-filter="">
#             Reiniciar
#         </a>
# </span>
# </div>
# <div class="Filters js-SearchFilters">
# <span class="Filters-label Filters-label--open"><span>Precio</span><i class="icon Filter-label--icon icon_i_109__minus"></i></span>
# <div class="js-FiltersContainer">
# <div class="Filters-content price">
# <!-- PRICE INPUT -->
# <div class="priceInput hide">
# <form method="post">
#       De <input class="js-InputMinPrice" pattern="\d*" type="text" value="0"/> à <input class="js-InputMaxPrice" data-max="30€" pattern="\d*" type="text" value="30"/> € <input class="button js-priceInput-submit" data-role="none" type="submit" value="OK"/>
# </form>
# <div class="priceInput-all js-priceInput-all"><i class="icon icon_i_039_cross_01"></i> <span>Reiniciar</span></div>
# </div>
# <!-- PRICE SLIDER -->
# <div class="priceSlider">
# <div class="sliderTotal">
#         100
#         resultados
#
#       </div>
# <input class="js-InputMinPrice" type="hidden" value="0"/>
# <input class="js-InputMaxPrice" type="hidden" value="30"/>
# <div class="sliderGuide">
# <span class="sliderSelected"></span>
# <a class="sliderMinSelector f-js-SliderMinSelector">
# <span class="sliderMinDisplay">
#             0€
#           </span>
# </a>
# <a class="sliderMaxSelector f-js-SliderMaxSelector">
# <span class="sliderMaxDisplay">
#             30€
#           </span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <span class="Filters-label Filters-label--open">
# <span>Fecha de lanzamiento</span>
# <i class="icon Filter-label--icon icon_i_109__minus"></i>
# </span>
# <div class="js-FiltersContainer">
# <div class="Filters-content">
# <a class="Filters-choice " data-filter="2!34" data-noaccent="Novedades - de 3 meses" href="https://www.fnac.es/n713/Libros-de-bolsillo-mas-vendidos?SFilt=2!34" title="Novedades - de 3 meses">
# <input class="check" id="filter_ee610a18-327e-492c-811b-2db1e68305c5" type="checkbox">
# <label class="Filters-choiceTxt " for="filter_ee610a18-327e-492c-811b-2db1e68305c5">
#                 Novedades - de 3 meses
#
#                 <span class="Filters-choiceCount">(6)</span>
# </label>
# </input></a>
# <a class="Filters-choice " data-filter="3!34" data-noaccent="3 - 6 meses" href="https://www.fnac.es/n713/Libros-de-bolsillo-mas-vendidos?SFilt=3!34" title="3 - 6 meses">
# <input class="check" id="filter_5e88d056-4d5f-450d-b57e-6dc81f2afcae" type="checkbox">
# <label class="Filters-choiceTxt " for="filter_5e88d056-4d5f-450d-b57e-6dc81f2afcae">
#                 3 - 6 meses
#
#                 <span class="Filters-choiceCount">(9)</span>
# </label>
# </input></a>
# <a class="Filters-choice " data-filter="4!34" data-noaccent="6 - 12 meses" href="https://www.fnac.es/n713/Libros-de-bolsillo-mas-vendidos?SFilt=4!34" title="6 - 12 meses">
# <input class="check" id="filter_2f9924e8-125c-4767-bd72-5a7ee80e4357" type="checkbox">
# <label class="Filters-choiceTxt " for="filter_2f9924e8-125c-4767-bd72-5a7ee80e4357">
#                 6 - 12 meses
#
#                 <span class="Filters-choiceCount">(12)</span>
# </label>
# </input></a>
# <a class="Filters-choice " data-filter="5!34" data-noaccent="+12 meses" href="https://www.fnac.es/n713/Libros-de-bolsillo-mas-vendidos?SFilt=5!34" title="+12 meses">
# <input class="check" id="filter_b219a0fa-8712-4a28-9a8f-99a2d58e288f" type="checkbox">
# <label class="Filters-choiceTxt " for="filter_b219a0fa-8712-4a28-9a8f-99a2d58e288f">
#                 +12 meses
#
#                 <span class="Filters-choiceCount">(73)</span>
# </label>
# </input></a>
# </div>
# </div>
# <span class="Filters-label Filters-label--open">
# <span>Vendedor</span>
# <i class="icon Filter-label--icon icon_i_109__minus"></i>
# </span>
# <div class="js-FiltersContainer">
# <div class="Filters-content">
# <a class="Filters-choice " data-filter="1!206" data-noaccent="Fnac.es" title="Fnac.es">
# <input class="check" id="filter_4ed78c07-92d6-4276-9b8e-2ac24a59da28" type="checkbox">
# <label class="Filters-choiceTxt " for="filter_4ed78c07-92d6-4276-9b8e-2ac24a59da28">
#                 Fnac.es
#
#                 <span class="Filters-choiceCount">(100)</span>
# </label>
# </input></a>
# <a class="Filters-choice " data-filter="15!206" data-noaccent="Agapea libros" title="Agapea libros">
# <input class="check" id="filter_cfcc326e-201a-46ef-86b0-3c35733f018e" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_cfcc326e-201a-46ef-86b0-3c35733f018e">
#                 Agapea libros
#
#                 <span class="Filters-choiceCount">(82)</span>
# </label>
# </a>
# <a class="Filters-choice " data-filter="84!206" data-noaccent="Artemis libros" title="Artemis libros">
# <input class="check" id="filter_40e1ddda-0fce-4c2f-9cdd-0383040cfaef" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_40e1ddda-0fce-4c2f-9cdd-0383040cfaef">
#                 Artemis libros
#
#                 <span class="Filters-choiceCount">(80)</span>
# </label>
# </a>
# <a class="Filters-choice " data-filter="83!206" data-noaccent="Popular libros" title="Popular libros">
# <input class="check" id="filter_6ae8576f-86fe-413e-b1cc-b00a5202ca50" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_6ae8576f-86fe-413e-b1cc-b00a5202ca50">
#                 Popular libros
#
#                 <span class="Filters-choiceCount">(70)</span>
# </label>
# </a>
# <a class="Filters-choice " data-filter="8368!206" data-noaccent="Clicon" title="Clicon">
# <input class="check" id="filter_fb6f52dc-58bc-425f-abee-2ad3b6c5b02b" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_fb6f52dc-58bc-425f-abee-2ad3b6c5b02b">
#                 Clicon
#
#                 <span class="Filters-choiceCount">(67)</span>
# </label>
# </a>
# <a class="Filters-choice " data-filter="53!206" data-noaccent="Ommcampuslibros" title="Ommcampuslibros">
# <input class="check" id="filter_b6d0fa0b-e5a1-4fe4-88fe-83a20b8eb6a3" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_b6d0fa0b-e5a1-4fe4-88fe-83a20b8eb6a3">
#                 Ommcampuslibros
#
#                 <span class="Filters-choiceCount">(65)</span>
# </label>
# </a>
# <a class="Filters-choice " data-filter="3089!206" data-noaccent="Libreriamaxtor" title="Libreriamaxtor">
# <input class="check" id="filter_bba82d52-ca44-4d4d-a9b5-98953ab1a723" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_bba82d52-ca44-4d4d-a9b5-98953ab1a723">
#                 Libreriamaxtor
#
#                 <span class="Filters-choiceCount">(45)</span>
# </label>
# </a>
# <a class="Filters-choice " data-filter="47!206" data-noaccent="Libreria praga" title="Libreria praga">
# <input class="check" id="filter_d5d94c35-7e00-4600-bb3d-ea34ec92c729" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_d5d94c35-7e00-4600-bb3d-ea34ec92c729">
#                 Libreria praga
#
#                 <span class="Filters-choiceCount">(27)</span>
# </label>
# </a>
# <a class="Filters-choice " data-filter="1058!206" data-noaccent="Ag libros" title="Ag libros">
# <input class="check" id="filter_f5e822f7-8356-421c-8383-deee53566d30" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_f5e822f7-8356-421c-8383-deee53566d30">
#                 Ag libros
#
#                 <span class="Filters-choiceCount">(14)</span>
# </label>
# </a>
# <a class="Filters-choice " data-filter="21!206" data-noaccent="Dreamers" title="Dreamers">
# <input class="check" id="filter_67cc78eb-e8d2-4fbe-8959-ffd82dd50bb7" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_67cc78eb-e8d2-4fbe-8959-ffd82dd50bb7">
#                 Dreamers
#
#                 <span class="Filters-choiceCount">(13)</span>
# </label>
# </a>
# <a class="Filters-choice " data-filter="1565!206" data-noaccent="Boreal" title="Boreal">
# <input class="check" id="filter_917d929a-9e2f-4f9a-a7f2-b57502e623eb" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_917d929a-9e2f-4f9a-a7f2-b57502e623eb">
#                 Boreal
#
#                 <span class="Filters-choiceCount">(2)</span>
# </label>
# </a>
# <a class="Filters-choice " data-filter="16!206" data-noaccent="Alzofora" title="Alzofora">
# <input class="check" id="filter_792dd7ef-9901-4dc6-9b1a-47652cba93ff" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_792dd7ef-9901-4dc6-9b1a-47652cba93ff">
#                 Alzofora
#
#                 <span class="Filters-choiceCount">(1)</span>
# </label>
# </a>
# </div>
# <button class="toggleFilters js-toggleFilters">
# <span class="js-toggleFilters-more"><i class="icon icon_i_059_arrow_bottom_01"></i>Ver más</span>
# <span class="js-toggleFilters-less"><i class="icon icon_i_053_arrow_top_01"></i>Ver menos</span>
# </button>
# </div>
# <span class="Filters-label Filters-label--open">
# <span>Formato</span>
# <i class="icon Filter-label--icon icon_i_109__minus"></i>
# </span>
# <div class="js-FiltersContainer">
# <div class="Filters-content">
# <a class="Filters-choice " data-filter="1627!100" data-noaccent="Bolsillo" title="Bolsillo">
# <input class="check" id="filter_2e464468-ca1f-41d3-8298-0f73febb83a2" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_2e464468-ca1f-41d3-8298-0f73febb83a2">
#                 Bolsillo
#
#                 <span class="Filters-choiceCount">(14)</span>
# </label>
# </a>
# <a class="Filters-choice " data-filter="1626!100" data-noaccent="Normal" title="Normal">
# <input class="check" id="filter_51c33fd9-699a-4844-a381-708586434c09" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_51c33fd9-699a-4844-a381-708586434c09">
#                 Normal
#
#                 <span class="Filters-choiceCount">(1)</span>
# </label>
# </a>
# </div>
# </div>
# <span class="Filters-label Filters-label--open">
# <span>Serie</span>
# <i class="icon Filter-label--icon icon_i_109__minus"></i>
# </span>
# <div class="js-FiltersContainer">
# <div class="Filters-content">
# <div class="filterFilters specificFilter">
# <span></span>
# <input type="text"/>
# </div>
# <a class="Filters-choice " data-filter="27!24" data-noaccent="Harry Potter" title="Harry Potter">
# <input class="check" id="filter_39b70a17-2d54-459c-b582-0b7b0e0a5efa" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_39b70a17-2d54-459c-b582-0b7b0e0a5efa">
#                 Harry Potter
#
#                 <span class="Filters-choiceCount">(4)</span>
# </label>
# </a>
# <a class="Filters-choice " data-filter="15!24" data-noaccent="Juego de Tronos" title="Juego de Tronos">
# <input class="check" id="filter_9810747a-9b33-48b8-baa5-626e6d82081b" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_9810747a-9b33-48b8-baa5-626e6d82081b">
#                 Juego de Tronos
#
#                 <span class="Filters-choiceCount">(1)</span>
# </label>
# </a>
# </div>
# </div>
# <span class="label Filters-label Filters-label--open">
# <span>Nota de los usuarios</span>
# <i class="icon Filter-label--icon icon_i_109__minus"></i>
# </span>
# <div class="js-FiltersContainer">
# <div class="Filters-content">
# <a class=" Filters-choice" data-filter="4!31">
# <input class="check" id="note4!31" type="checkbox"/>
# <label class="Filters-choiceTxt">
# <img alt="5 estrellas" src="https://www.fnac.es/nav/images/etoiles/stars5.png"/>
# <span class="Filters-choiceCount">(8)</span>
# </label>
# </a>
# <a class=" Filters-choice" data-filter="3!31">
# <input class="check" id="note3!31" type="checkbox"/>
# <label class="Filters-choiceTxt">
# <img alt="4 estrellas" src="https://www.fnac.es/nav/images/etoiles/stars4.png"/>
# <strong></strong>
# <span class="Filters-choiceCount">(9)</span>
# </label>
# </a>
# <a class=" Filters-choice" data-filter="2!31">
# <input class="check" id="note2!31" type="checkbox"/>
# <label class="Filters-choiceTxt">
# <img alt="3 estrellas" src="https://www.fnac.es/nav/images/etoiles/stars3.png"/>
# <strong></strong>
# <span class="Filters-choiceCount">(2)</span>
# </label>
# </a>
# </div>
# </div>
# <span class="Filters-label Filters-label--open">
# <span>Estado</span>
# <i class="icon Filter-label--icon icon_i_109__minus"></i>
# </span>
# <div class="js-FiltersContainer">
# <div class="Filters-content">
# <a class="Filters-choice " data-filter="3!28" data-noaccent="nuevos" title="Nuevos">
# <input class="check" id="filter_dd67ffa0-7e91-4b34-bca1-49247cc11574" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_dd67ffa0-7e91-4b34-bca1-49247cc11574">
#                 Nuevos
#
#                 <span class="Filters-choiceCount">(100)</span>
# </label>
# </a>
# <a class="Filters-choice " data-filter="1!28" data-noaccent="ocasion" title="Ocasión">
# <input class="check" id="filter_17ba3591-9421-43ec-95c1-0ff34fb1dc9a" type="checkbox"/>
# <label class="Filters-choiceTxt " for="filter_17ba3591-9421-43ec-95c1-0ff34fb1dc9a">
#                 Ocasión
#
#                 <span class="Filters-choiceCount">(45)</span>
# </label>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="js-SearchSideAdvertising" id="advertisingSidebar">
# <div data-page="www.fnac.es/searchresult" id="sas_47233" style="margin:0 auto;"></div>
# </div>
# </div>
# <div class="Main resultList js-SearchResult">
# <div class="Main-searchWrapper">
# <!-- breadcrumbs -->
# <div class="Breadcrumb">
# <ul class="Breadcrumb-list">
# <li class="Breadcrumb-item" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a class="Breadcrumb-link" href="https://www.fnac.es/" itemprop="url"><span itemprop="title">Home</span></a>
# </li>
# <li class="Breadcrumb-item" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <span>-</span>
# <a class="Breadcrumb-link" href="https://www.fnac.es/home/book.aspx" itemprop="url">
# <span itemprop="title">Libros </span>
# </a>
# </li>
# <li class="Breadcrumb-item" itemscope="">
# <span>-</span>
# <span itemprop="title">Libros de bolsillo más vendidos</span>
# </li>
# </ul>
# </div>
# <!-- Tête de liste -->
# <div class="Search-title">
# <h1>
#     Libros de bolsillo más vendidos
#   </h1>
# <button class="btn submenu-toggler js-submenu-toggler">
# <i class="icon icon_i_028_list"></i>
#     Filtrer
#   </button>
# </div>
# <!-- HookLogic -->
# <div class="js-hl-service" data-keyword="Libros de bolsillo más vendidos" data-module="SearchCarousel" data-type="S" id="hl_1">
# </div>
# <div class="top-toolbar clearfix">
# <div class="top-toolbar-right">
# <span class="Item-onPage">
# <select class="articlePerPage">
# <option data-nb="20" selected="" value="20">20 por página</option>
# <option data-nb="50" data-url="" value="50">50 por página</option>
# <option data-nb="100" data-url="" value="100">Todos</option>
# </select>
# </span>
# <span class="switchListMosaic">
# <ul class="Switch-list">
# <li class="Switch-item">
# <a class="mosaicButton middle section" title="Mosaico">
# <i class="icon icon_i_187_Fnac_Mosaique"></i>
#                     Mosaico
# ...
# </p>
# <ul class="Footer-bottomList">
# <li class="Footer-bottomItem Footer-sitemap">
# <a href="https://www.fnac.es/Navigation/plan.aspx#bl=footer">Plano del sitio</a>
# </li>
# <p class="Footer-bottomItem Footer-sitemap">
#                         © Fnac 2017.
#                             <a href="https://www.fnac.es/home/book.aspx#bl=categoryfooterlink">Libros, eBooks y Papelería</a> -
#                             <a href="https://www.fnac.es/infantil#bl=categoryfooterlink">Niños, Juguetes</a> -
#                             <a href="https://www.fnac.es/home/music.aspx#bl=categoryfooterlink">Música e Instrumentos</a> -
#                             <a href="https://www.fnac.es/home/video.aspx#bl=categoryfooterlink">Cine y Series TV</a> -
#                             <a href="https://www.fnac.es/merchandising#bl=categoryfooterlink">Merchandising y Coleccionismo</a> -
#                             <a href="https://www.fnac.es/juegos#bl=categoryfooterlink">Videojuegos y Consolas</a> -
#                             <a href="https://www.fnac.es/ordenador-PC#bl=categoryfooterlink">Informática</a> -
#                             <a href="https://www.fnac.es/telefono-MP3-GPS#bl=categoryfooterlink">Smartphones y Conectables</a> -
#                             <a href="https://www.fnac.es/foto-videocamara#bl=categoryfooterlink">Fotografía y Videocámaras</a> -
#                             <a href="https://www.fnac.es/TV-video#bl=categoryfooterlink">TV y Home Cinema</a> -
#                             <a href="https://www.fnac.es/sonido-mp3-hifi#bl=categoryfooterlink">Sonido, HI-FI y Auriculares</a> -
#                             <a href="https://www.fnac.es/fnac-active#bl=categoryfooterlink">Deporte, Salud y Bienestar</a> -
#                             <a href="https://www.fnac.es/hogar#bl=categoryfooterlink">Hogar y Electrodomésticos</a> -
#                             <a href="https://www.fnac.es/pack-experiencia#bl=categoryfooterlink">Packs experiencia</a> -
#                             <a href="https://shops.ticketmasterpartners.com/fnac-entradas/#bl=categoryfooterlink">Venta de Entradas</a> -
#                             <a href="https://reveladofnac.snappybook.com/#bl=categoryfooterlink">Revelado digital</a>
# </p>
# <p class="Footer-bottomItem Footer-sitemap" style="font-size:10px;">
#                         FNAC es una marca registrada explotada en España bajo licencia de FNAC S.A.
# 		                <br>Grandes Almacenes Fnac España, S.A.U Paseo de la Finca, 1 Edificio 11 - 2ª planta 28223 Pozuelo de Alarcón (Madrid)
# 		                <br>CIF: A-80/500200 Registro Mercantil de Madrid el 26/05/93, Tomo 6244, Hoja M-101.824, Folio 189. Inscripción 1ª
#                         </br></br></p>
# </ul>
# </div>
# </div>
# </footer>
# </div>
# </div>
#
#
# <!-- - - - - - - End content - - - - - - - -->
# <div class="FlashMessage js-FlashMessage">
# <button class="FlashMessage-close js-FlashMessage-close"><i class="icon icon_i_037_cross_03 crasyegg-test"></i></button>
# <span class="FlashMessage-title"><i class="icon icon_i_121_Alert"></i>  Atención</span>
#     Ha ocurrido un error, por favor inténtalo de nuevo más tarde.
# </div>
# <div id="contentOnTop">
# <div class="block js-Cnilbar" id="htmlPopinCookies">
# <p class="clearfix">
# <em>
# <span>Uso de las cookies</span>Si continúas con tu navegación sin modificar tus parámetros, aceptas la utilización de cookies o de tecnologías similares para disponer de servicios y de ofertas adaptadas a tus puntos de interés, así como para asegurar las transacciones en nuestra web. Para más información, gestionar o modificar los parámetros,</em></p></div></div>
#
# <a href="https://www.fnac.es/cookies" rel="nofollow">
#                 clica aquí</a>
# <i class="icon icon_i_037_cross_03 close js-Cnilbar-close"></i>
#
#
#
# <div class="Overlay js-Overlay">
# <!--<div class="Spinner Spinner--centered js-OverlaySpinner"></div>-->
# <div class="fnac-loader js-OverlaySpinner"></div>
# </div>
# <div class="js-scrollTop">
# <a class="js-scrollTopBtn btn-backToTop" href="#">
# <i class="icon icon_i_053_arrow_top_01"></i>
# </a>
# </div>
# <div class="AndroidMessage">
# <div class="AndroidMessage-content">
# <button class="AndroidMessage-close"><i class="icon icon_i_037_cross_03"></i></button>
# <span class="AndroidMessage-title">Vraiment désolé...</span>
# <p class="AndroidMessage-text">Le site Fnac.com n'est pas parfaitement optimisé sur ce navigateur. Votre expérience serait bien meilleure si vous en téléchargiez un autre</p>
# <a class="AndroidMessage-browser AndroidMessage-browser--firefox" href="https://play.google.com/store/apps/details?id=org.mozilla.firefox">Firefox</a>
# <a class="AndroidMessage-browser AndroidMessage-browser--chrome" href="https://play.google.com/store/apps/details?id=com.android.chrome">Chrome</a>
# <a class="AndroidMessage-browser AndroidMessage-browser--opera" href="https://play.google.com/store/apps/details?id=com.opera.browser">Opera</a>
# </div>
# </div>
# <div id="dvPopinRedirect"></div>
# <script id="wishlistThumbnailBaseTemplate" type="x-tmpl-mustache">
# <div class="wishlist">
#     <span class="wishlist-close icon close icon_i_037_cross_03 {{#hideCloseIcon}}hide{{/hideCloseIcon}}"></span>
#     <div class="wishlist-list list">
#         <div class="wishlist-listTitle title">Mis listas</div>
#         <div id="added" class="wishlist-added hide">
#             <span class="icon icon_i_102_check_03"></span>
#             <span class="text"></span>
#         </div>
#         <div class="wishlist-wrapper">
#         </div>
#     </div>
#     <div class="wishlist-tools">
#         <div class="wishlist-form formBox">
#             <input type="text" class="wishlist-input Field-input" placeholder="Crear una lista nueva" />
#             <span class="wishlist-submit CreateWishlistAndAddArticle">OK</span>
#         </div>
#     </div>
# </div>
# </script>
# <script id="wishlistThumbnailTemplate" type="x-tmpl-mustache">
# {{#wishlists}}
# <div class="wishlist-item">
#     <input type="checkbox" class="wishList-itemInput" {{#hasThisArticle}} checked="checked" {{/hasThisArticle}} id="chkExpressPluss{{id}}" data-wishlistId="{{id}}" />
#     <label class="wishlist-label AddArticleToWishlist" for="chkExpressPluss{{id}}">
#         <span class="wishlist-itemText">{{name}}</span>
#     </label>
# </div>
# {{/wishlists}}
# </script>
# <script type="text/javascript">"undefined"!=typeof _satellite&&_satellite.pageBottom();</script>
# <noscript>
# <iframe height="1" src="http://redirect28.tagcommander.com/utils/noscript.php?id=1&amp;mode=iframe&amp;template_type=&amp;page_name=Libros%3aLibros+de+bolsillo+m%c3%a1s+vendidos" width="1"></iframe>
# </noscript>
# <!--ScriptWriter-->
# <script type="text/javascript">
#                 window.addEventListener('load', function () {
#                     AppCore.ready(function(){
#                         AppCore.modules.ready('searchAutocomplete', function () {
#
#
#                             if (AppCore.defaults != null && AppCore.defaults.searchAutocomplete != null)
#                                 AppCore.modules.searchAutocomplete.defaultAB = AppCore.defaults.searchAutocomplete.defaultAB;
#
#                             if (AppCore.modules.searchAutocomplete.defaultAB == null)
#                                 AppCore.modules.searchAutocomplete.defaultAB =  'A' ;
#                             AppCore.modules.searchAutocomplete.urlAutocomplete = "https://autocomplete-es.ws.fnac.com/search-autocomplete/autocomplete?client=1&method=GetCommonSuggest";
#                             AppCore.modules.searchAutocomplete.groups = [
#                                 {
#                                     name: "Sugerencias de palabras clave",
#                                             type: 's',
#                                             max: 5,
#                                             maxChars: 33,
#                                             order: 0,
#                                             orderParamUrl : 1
#                                         },
#                                             {
#                                                 name: "Ver las secciones",
#                                                 type: 'm',
#                                                 max: 4,
#                                                 maxChars: 33,
#                                                 order: 3,
#                                                 orderParamUrl : 2
#                                             },
#                                             {
#                                                 name: "Productos",
#                                                 type: 'p',
#                                                 max: 6,
#                                                 maxChars: 50,
#                                                 order: 2,
#                                                 orderParamUrl : 0
#                                             }
#                                     ];
#
#                             AppCore.start("searchAutocomplete");
#                         });
#                         $('.realSelect').comboToList({ hiddenInputName: 'SCat' });
#                     });
#                 }, false);
#             </script>
# <script type="text/javascript"> var tc_vars = { template_type: "sous_home", template_name: "4_sous_homes_shi_pt", arbo_niv1: "Libros", arbo_niv2: "Libros de bolsillo más vendidos", arbo_niv3: "", arbo_niv4: "", arbo_niv5: "", arbo_niv6: "", page_name: "Libros:Libros de bolsillo más vendidos", env_language: "es-ES", env_country: "ES", user_id: "", user_segment: "Non-Adherent", user_age: "", user_gender: "", user_subscription_date: "", user_subscription_newsletter: "", express_plus: "", eligibility_express_plus_trial: "", user_segment_type: "", user_sid: "3d777ed5-9e0d-4372-9654-ecf264447518", user_crm_uid: "", user_first_name: "", user_email: "", search_kw: "", search_nb_results: "", search_current_page: "", search_category: "", search_refine_category: "", search_refine_comb: "", search_type: "", product_name: "", product_id: "", product_ref: "", product_ref_id: "", product_stock: "", product_category: "", product_vendor: "", product_unitprice_ati: "", product_discount_ati: "", product_unitprice_tf: "", product_discount_tf: "", product_currency: "", product_trademark: "", product_url_page: "", product_picture_url: "", product_isbundle: "", product_breadcrumb_id: "", product_rating: "", cart_id: "", order_id: "", orderUserRefs: "", order_amount: "", order_amount_ati: "", order_amount_wt: "", order_amount_ati_with_sf: "", order_amount_tf_with_sf: "", order_currency: "", order_pay_method: "", order_new_client: "", order_nb_products: "0", order_promo_code: "", order_state: "", order_shipping_method: "", order_ship_ati: "", order_ship_tf: "", order_tax: "", order_zip: "", order_products: [], nav_typvt: "0", nav_support: "0", product_unitpricemp: "", product_unitprice: "", product_unitprice_discount: "", product_offrebuybox: "0", product_pricemode: "0", product_availabilitype: "0", product_productflagchoosebox: "0", product_availability: "", nav_ip: "", nav_origine: "", nav_objectid: "", nav_pathid: "", user_auth: "0", recommendation_id: "", list_products: [], email : "" , email: "" , product_itemType: "" , product_EAN: "" , product_PartNumber: "" }; </script> <script defer="" src="https://www.fnac.es/static/tc/O4-u_WrXHDKyaijfRKPDeOSyDbM0/load_exec.1.D.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#     var prop40 = "Arbo_N1", s_account = 'fnacesprod', s_trackingServer = 'metrics.fnac.es', s_trackingServerSecure = 'smetrics.fnac.es';
#
#     var s_translationsEnum = {"0":"","1":"Moteur","2":"","3":"","4":"Moteur","5":"","6":"","7":"","8":"","9":"","13":"","20":"","30":"","40":"","41":"","50":"","60":"","70":"","80":"","101":"Fiche Produit","102":"Zoom Produit","103":"Comparateur","104":"Liste Produits","105":"MyFnac","106":"FI:Mini-FA","107":"FI:Ventes Additionelles","108":"FI:Univers de l’intervenant","109":"","110":"Fiche Produit PT:Services","111":"FP Fcom:BuyBox","112":"FP Fcom:ChoiceBox","113":"Liste d’offres","114":"Boutique","115":"FP MP:BuyBox","116":"FP MP:ChoiceBox","117":"Selection Artistes","118":"","119":"Page Label: Mini-FA","120":"","121":"","122":"Fiche Serie","123":"Panier Flottant : Recommandations","-3":""};
#   </script>
# <script src="//assets.adobedtm.com/36a49d3be67853da4abfda89e348d53be64d9ffb/satelliteLib-3385dc4f3cb5ad7de91ee1b8a82118e6f6d83351.js"></script>
# <script type="text/javascript">
#     if (typeof s !== 'undefined') {
#       s.charSet="UTF-8";
#       s.pageName = "Libros:Libros de bolsillo más vendidos";
#       s.server = "FCS2WPFWEBFD3";
#       s.channel = "";
#       s.linkInternalFilters = "fnac.es";
#       s.pageType = "";
#       s.prop51="Web Desktop"
#       s.prop1="Libros"
#       s.prop2="Libros de bolsillo más vendidos"
#       s.prop7=""
#       s.prop40="Arbo_N1"
#
#       s.prop20 = "";s.prop21 = "";s.campaign = "";s.state = "";s.zip = "";s.events = "";s.products = "";s.purchaseID = "";
#       s.eVar1 = "";s.eVar2 = "browse";s.eVar3 = "713";s.eVar4 = "";s.eVar5 = "";
#       s.eVar6 = "";s.eVar36 = "";s.eVar37 = "";s.eVar12 = "";s.eVar15 = "";
#       s.eVar17 = "";s.eVar19 = "";s.prop8 = "";s.eVar45 = "KISS";s.eVar48 = "";
#       s.eVar56 = "";s.prop57 = "Non identifie";s.eVar39 = "";
#       s.eVar82 = "";
#
#
#       s.tracksent=true;
#       var s_code=s.t();s_code&&document.write(s_code);
#
#       window.Kameleoon&&Kameleoon.API.processOmniture(s);
#     }
#   </script>
# <script type="text/javascript">
#         if(navigator.appVersion.indexOf('MSIE')>=0)document.write(unescape('%3C')+'\!-'+'-');
#     </script>
# <script type="text/javascript"> var tc_vars = { template_type: "", template_name: "", arbo_niv1: "Libros", arbo_niv2: "Libros de bolsillo más vendidos", arbo_niv3: "", arbo_niv4: "", arbo_niv5: "", arbo_niv6: "", page_name: "Libros:Libros de bolsillo más vendidos", env_language: "es-ES", env_country: "ES", user_id: "", user_segment: "Non-Adherent", user_age: "", user_gender: "", user_subscription_date: "", user_subscription_newsletter: "", express_plus: "", eligibility_express_plus_trial: "", user_segment_type: "", user_sid: "3d777ed5-9e0d-4372-9654-ecf264447518", user_crm_uid: "", user_first_name: "", user_email: "", search_kw: "", search_nb_results: "", search_current_page: "", search_category: "", search_refine_category: "", search_refine_comb: "", search_type: "", product_name: "", product_id: "", product_ref: "", product_ref_id: "", product_stock: "", product_category: "", product_vendor: "", product_unitprice_ati: "", product_discount_ati: "", product_unitprice_tf: "", product_discount_tf: "", product_currency: "", product_trademark: "", product_url_page: "", product_picture_url: "", product_isbundle: "", product_breadcrumb_id: "", product_rating: "", cart_id: "", order_id: "", orderUserRefs: "", order_amount: "", order_amount_ati: "", order_amount_wt: "", order_amount_ati_with_sf: "", order_amount_tf_with_sf: "", order_currency: "", order_pay_method: "", order_new_client: "", order_nb_products: "0", order_promo_code: "", order_state: "", order_shipping_method: "", order_ship_ati: "", order_ship_tf: "", order_tax: "", order_zip: "", order_products: [], nav_typvt: "0", nav_support: "0", product_unitpricemp: "", product_unitprice: "", product_unitprice_discount: "", product_offrebuybox: "0", product_pricemode: "0", product_availabilitype: "0", product_productflagchoosebox: "0", product_availability: "", nav_ip: "", nav_origine: "", nav_objectid: "", nav_pathid: "", user_auth: "0", recommendation_id: "", list_products: [], email : "" , email: "" , product_itemType: "" , product_EAN: "" , product_PartNumber: "" }; </script> <script defer="" src="https://www.fnac.es/static/tc/O4-u_WrXHDKyaijfRKPDeOSyDbM0/load_exec.1.D.js" type="text/javascript"></script>
# <!--/ScriptWriter-->
# <script src="https://www.fnac.es/static/jsg/EJIiYDheH9ejtDVKCElvjIz2t9M0/footer1.js"></script>

# %% [markdown]
# ### Recuperar los datos de la tabla
#
# Las tablas de HTML se definen con tres etiquetas: `<table>` para crear la tabla, `<tr>` para crear cada fila y `<td>` para crear cada columna.

# %%
from IPython.display import HTML
s = """
<table>
    <tr>
      <th><strong>Curso</strong></th>
      <th><strong>Horas</strong></th>
    </tr>
 
    <tr>
      <td>CSS</td>
      <td>20</td>
    </tr>
 
    <tr>
      <td>HTML</td>
      <td>20</td>
    </tr>
</table>"""
HTML(s)
# Out:
# <table>
#     <tr>
#       <th><strong>Curso</strong></th>
#       <th><strong>Horas</strong></th>
#     </tr>
#
#     <tr>
#       <td>CSS</td>
#       <td>20</td>
#     </tr>
#
#     <tr>
#       <td>HTML</td>
#       <td>20</td>
#     </tr>
# </table>

# %% [markdown]
# __Ejemplo:__ Queremos recuperar los datos de la tabla que aparece en la página  [Municipios Madrid](https://es.wikipedia.org/wiki/Anexo:Municipios_de_la_Comunidad_de_Madrid).
#
# En este caso utilizamos el método __find_all()__ que lo que hace es coger todos los fragmentos del HTML que correpondan a las etiquetas __tr__ y __td__.

# %%
content = {}
# Obtenemos cada una de las filas de la tabla 
titulos = soup.find_all('a', {"class":" js-minifa-title"})
for r in titulos:
    print(r.string)
    
    
    # Seleccionamos las celdas de la tabla (td)
   # celdas=r.find_all('td')
    # ignoramos la primera celda, que no tiene elementos td sino th (ver HTML de la página web)
    #if len(celdas)>0:
        # En lugar de un separador de miles, en el HTML se ha usado un caracter 
        # parecido a un espacio en blanco
        # por lo que en la celda de habitantes hay que eliminar todos 
        # los caracteres que no sean números
 
     #   content[celdas[0].string] = { 'población': int( ''.join(c for c in celdas[1].string if c.isdigit())),
      #                                'superficie': int( ''.join(c for c in celdas[2].string if c.isdigit())),
#                                      'altitud': int( ''.join(c for c in celdas[6].string if c.isdigit())),}
# Out:
# It (Eso)
# Juego de Tronos - Fantasy : Canción de Hielo y Fuego 1. Juego de Tronos. Edición Omnium
# Canción de Hielo y Fuego 2. Choque de reyes. Edición Omnium
# 1984
# Canción de hielo y fuego 3. Tormenta de espadas Edición Omnium
# La chica del tren
# El pistolero (La Torre Oscura I)
# Harry Potter - Harry Potter y la piedra filosofal : Harry Potter y la piedra filosofal
# El nombre del viento
# El monje que vendió su Ferrari
# Legado en los huesos
# Ofrenda a la tormenta
# Mi isla
# Rebelión en la granja
# La niebla y la doncella
# Festín de cuervos
# Historia de un canalla
# American gods
# Gente tóxica
# Un mundo feliz

# %%
content    # ejecutar esta celda
# Out:
# {}

# %% [markdown]
# #### 1 Ejercicio

# %% [markdown]
# Partiendo del diccionario `content`, calcula la población total de todos los municipios.

# %%
# Sol:
suma = 0


for d in content.values():
    suma = suma + d['población']
suma
# Out:
# 6466996

# %% [markdown]
# #### 2 Ejercicio
#
# Partiendo del diccionario `content`, obtener un listado de los municipios cuya altitud sea por encima de los 700 metros.

# %%
# Sol:
lista = []
for x, y  in content.items():
    if y['altitud']>700:
        lista.append(x)
    else:
        pass
lista
# Out:
# ['La Acebeda',
#  'Alameda del Valle',
#  'Alcorcón',
#  'Algete',
#  'Alpedrete',
#  'Anchuelo',
#  'El Atazar',
#  'Becerril de la Sierra',
#  'Belmonte de Tajo',
#  'El Berrueco',
#  'Berzosa del Lozoya',
#  'El Boalo',
#  'Braojos de la Sierra',
#  'Brea de Tajo',
#  'Buitrago del Lozoya',
#  'Bustarviejo',
#  'Cabanillas de la Sierra',
#  'La Cabrera',
#  'Cadalso de los Vidrios',
#  'Campo Real',
#  'Canencia',
#  'Cenicientos',
#  'Cercedilla',
#  'Cervera de Buitrago',
#  'Chinchón',
#  'Collado Mediano',
#  'Collado Villalba',
#  'Colmenar de Oreja',
#  'Colmenar Viejo',
#  'Colmenarejo',
#  'Corpa',
#  'El Escorial',
#  'Fresnedillas de la Oliva',
#  'Galapagar',
#  'Garganta de los Montes',
#  'Gargantilla del Lozoya y Pinilla de Buitrago',
#  'Gascones',
#  'Guadalix de la Sierra',
#  'Guadarrama',
#  'La Hiruela',
#  'Horcajo de la Sierra-Aoslos',
#  'Horcajuelo de la Sierra',
#  'Hoyo de Manzanares',
#  'Lozoya',
#  'Lozoyuela-Navas-Sieteiglesias',
#  'Madarcos',
#  'Majadahonda',
#  'Manzanares el Real',
#  'Miraflores de la Sierra',
#  'El Molar',
#  'Los Molinos',
#  'Montejo de la Sierra',
#  'Moralzarzal',
#  'Navacerrada',
#  'Navalafuente',
#  'Navalagamella',
#  'Navarredonda y San Mamés',
#  'Navas del Rey',
#  'Nuevo Baztán',
#  'Olmeda de las Fuentes',
#  'Patones',
#  'Pedrezuela',
#  'Pezuela de las Torres',
#  'Pinilla del Valle',
#  'Piñuécar-Gandullas',
#  'Pozuelo del Rey',
#  'Prádena del Rincón',
#  'Puebla de la Sierra',
#  'Puentes Viejas',
#  'Rascafría',
#  'Redueña',
#  'Ribatejada',
#  'Robledillo de la Jara',
#  'Robledo de Chavela',
#  'Robregordo',
#  'Las Rozas de Madrid',
#  'Rozas de Puerto Real',
#  'San Lorenzo de El Escorial',
#  'Santa María de la Alameda',
#  'Santorcaz',
#  'Los Santos de la Humosa',
#  'La Serna del Monte',
#  'Somosierra',
#  'Soto del Real',
#  'Torrelaguna',
#  'Torrelodones',
#  'Torremocha de Jarama',
#  'Tres Cantos',
#  'Valdaracete',
#  'Valdeavero',
#  'Valdemanco',
#  'Valdemaqueda',
#  'Valdemorillo',
#  'Valdepiélagos',
#  'Valdilecha',
#  'Valverde de Alcalá',
#  'El Vellón',
#  'Venturada',
#  'Villalbilla',
#  'Villarejo de Salvanés',
#  'Villavieja del Lozoya',
#  'Zarzalejo']
